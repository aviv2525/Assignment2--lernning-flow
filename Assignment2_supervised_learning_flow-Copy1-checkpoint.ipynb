# %% [markdown]
# ## Assignment2 - Supervised Learning flow

# %% [markdown]
# ### Part 1 - Student details:
# * Please write the First Name and last 4 digits of the i.d. for each student. For example:
# <pre>Israel 9812</pre>

# %%
# student 1:Aviv 7089
# student 2:Yotam 7816
# student 3:Amit 3658
# student 4:
# (optional) student 5:
# (optional) student 6:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
from sklearn.model_selection import cross_val_score  # Import cross_val_score for cross-validation
from sklearn.preprocessing import StandardScaler  # Import StandardScaler for feature standardization
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# Display the first few rows of each dataset to understand its structure
train_data = pd.read_csv('wine_test.csv')
print("Train Data:")
train_data.head()
# Out:
# Train Data:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    13.78        2.76  2.30               22.0       90.0           1.35
# 1    14.02        1.68  2.21               16.0       96.0           2.65
# 2    13.17        5.19  2.32               22.0       93.0           1.74
# 3    11.03        1.51  2.20               21.5       85.0           2.46
# 4    13.40        3.91  2.48               23.0      102.0           1.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        0.68                  0.41             1.03             9.58  0.70
# 1        2.33                  0.26             1.98             4.70  1.04
# 2        0.63                  0.61             1.55             7.90  0.60
# 3        2.17                  0.52             2.01             1.90  1.71
# 4        0.75                  0.43             1.41             7.30  0.70
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# Display the first few rows of each dataset to understand its structure
test_data = pd.read_csv('wine_train.csv')
print("\nTest Data:")
test_data.head()
# Out:
# Test Data:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    12.08        1.83  2.32               18.5       81.0           1.60
# 1    13.58        2.58  2.69               24.5      105.0           1.55
# 2    12.37        0.94  1.36               10.6       88.0           1.98
# 3    11.82        1.72  1.88               19.5       86.0           2.50
# 4    13.16        3.57  2.15               21.0      102.0           1.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        1.50                  0.52             1.64             2.40  1.08
# 1        0.84                  0.39             1.54             8.66  0.74
# 2        0.57                  0.28             0.42             1.95  1.05
# 3        1.64                  0.37             1.42             2.06  0.94
# 4        0.55                  0.43             1.30             4.00  0.60
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# Display basic statistics

print("Train Data Statistics:")
train_data.describe()
# Out:
# Train Data Statistics:
#          alcohol  malic_acid        ash  alcalinity_of_ash   magnesium  \
# count  36.000000   36.000000  36.000000          36.000000   36.000000
# mean   13.013889    2.488611   2.385556          19.791667   98.944444
# std     0.904962    1.210778   0.238716           3.308550   16.626905
# min    11.030000    0.990000   1.950000          14.000000   70.000000
# 25%    12.320000    1.670000   2.207500          16.950000   89.000000
# 50%    13.110000    1.900000   2.310000          20.000000   96.000000
# 75%    13.757500    3.202500   2.560000          22.000000  102.250000
# max    14.830000    5.800000   2.920000          28.500000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count      36.000000   36.000000             36.000000        36.000000
# mean        2.212778    1.893889              0.421667         1.705278
# std         0.569845    0.974970              0.134302         0.678846
# ...

# %%
print("\nTest Data Statistics:")
test_data.describe()
# Out:
# Test Data Statistics:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  142.000000  142.000000  142.000000         142.000000  142.000000
# mean    12.997254    2.297746    2.361690          19.419718   99.943662
# std      0.789931    1.093317    0.283231           3.354815   13.683751
# min     11.410000    0.740000    1.360000          10.600000   78.000000
# 25%     12.370000    1.592500    2.222500          17.250000   88.000000
# 50%     13.050000    1.865000    2.360000          19.250000   98.000000
# 75%     13.637500    3.020000    2.557500          21.375000  108.000000
# max     14.750000    5.650000    3.230000          30.000000  151.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     142.000000  142.000000            142.000000       142.000000
# mean        2.315986    2.063592              0.346690         1.561901
# ...

# %%
# Visualizations
# Pairplot: Visualize relationships between pairs of features
sns.pairplot(train_data)
plt.show()

# Histogram Visualize the correlation between features (e.g., 'alcohol')
plt.figure(figsize=(10, 6))
sns.histplot(train_data['alcohol'], bins=30, kde=True)
plt.title('Distribution of Alcohol Content')
plt.xlabel('Alcohol')
plt.ylabel('Frequency')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Part 3 - Training flow
# Use the best combination of feature engineering, model (algorithm and hyperparameters) from the experiment part (part 2)

# %%
# Load the training and test datasets
train_data = pd.read_csv('wine_train.csv')
test_data = pd.read_csv('wine_test.csv')

# Separate features (X) and target variable (y) for training and test data
X_train = train_data.drop('target', axis=1)  # Drop the target column to get the features
y_train = train_data['target']  # Extract the target column
X_test = test_data.drop('target', axis=1)
y_test = test_data['target']


# Standardize the features (mean=0, std=1)
scaler = StandardScaler()  # Create a StandardScaler object
X_train_scaled = scaler.fit_transform(X_train)  # Fit the scaler on the training data and transform it
X_test_scaled = scaler.transform(X_test)  # Transform the test data using the same scaler

# Convert the scaled data back to DataFrame for better readability in printing
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Print the standardized features
print("\nStandardized training features (X_train_scaled):")
X_train_scaled_df.head()  # Print the first 5 rows of the scaled training features
# Out:
# Standardized training features (X_train_scaled):
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0 -1.165293   -0.429338 -0.147716          -0.275119  -1.389292
# 1  0.740330    0.259077  1.163262           1.519686   0.370822
# 2 -0.796872   -1.246256 -3.549173          -2.638279  -0.875925
# 3 -1.495601   -0.530305 -1.706717           0.024015  -1.022601
# 4  0.206756    1.167784 -0.750057           0.472716   0.150808
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0      -1.123620   -0.562603              1.479415         0.144876
# 1      -1.202087   -1.221446              0.369703        -0.040628
# 2      -0.527274   -1.490973             -0.569283        -2.118278
# 3       0.288779   -0.422849              0.198979        -0.263233
# 4      -1.280554   -1.510938              0.711153        -0.485839
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# ...

# %%
print("\nStandardized test features (X_test_scaled):")
X_test_scaled_df.head()  # Print the first 5 rows of the scaled test features
# Out:
# Standardized test features (X_test_scaled):
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.994413    0.424296 -0.218580           0.771850  -0.729249
# 1  1.299313   -0.567021 -0.537466          -1.022955  -0.289221
# 2  0.219460    2.654759 -0.147716           0.771850  -0.509235
# 3 -2.499229   -0.723061 -0.572898           0.622283  -1.095939
# 4  0.511655    1.479865  0.419194           1.070985   0.150808
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0      -1.515954   -1.381166              0.540428        -0.986701
# 1       0.524179    0.265941             -0.740008         0.775592
# 2      -0.903914   -1.431078              2.247677        -0.022078
# 3       0.226006    0.106222              1.479415         0.831243
# 4      -0.809754   -1.311288              0.711153        -0.281784
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Load the training and test datasets
train_data = pd.read_csv('wine_train.csv')
test_data = pd.read_csv('wine_test.csv')

# Separate features (X) and target variable (y) for training and test data
X_train = train_data.drop('target', axis=1)  # Drop the target column to get the features
y_train = train_data['target']  # Extract the target column
X_test = test_data.drop('target', axis=1)
y_test = test_data['target']


# Apply MinMaxScaler (scales features to a range between 0 and 1)
scaler = MinMaxScaler()  # Create a MinMaxScaler object
X_train_scaled = scaler.fit_transform(X_train)  # Fit the scaler on the training data and transform it
X_test_scaled = scaler.transform(X_test)  # Transform the test data using the same scaler

# Convert the scaled data back to DataFrame for better readability in printing
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Print the standardized features
print("\nStandardized training features (X_train_scaled):")
X_train_scaled_df.head()  # Print the first 5 rows of the scaled training features
# Out:
# Standardized training features (X_train_scaled):
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.200599    0.221996  0.513369           0.407216   0.041096
# 1  0.649701    0.374745  0.711230           0.716495   0.369863
# 2  0.287425    0.040733  0.000000           0.000000   0.136986
# 3  0.122754    0.199593  0.278075           0.458763   0.109589
# 4  0.523952    0.576375  0.422460           0.536082   0.328767
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.213793    0.244726                  0.78         0.386076
# 1       0.196552    0.105485                  0.52         0.354430
# 2       0.344828    0.048523                  0.30         0.000000
# 3       0.524138    0.274262                  0.48         0.316456
# 4       0.179310    0.044304                  0.60         0.278481
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# ...

# %%
print("\nStandardized test features (X_test_scaled):")
X_test_scaled_df.head()  # Print the first 5 rows of the scaled test features
# Out:
# Standardized test features (X_test_scaled):
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.709581    0.411405  0.502674           0.587629   0.164384
# 1  0.781437    0.191446  0.454545           0.278351   0.246575
# 2  0.526946    0.906314  0.513369           0.587629   0.205479
# 3 -0.113772    0.156823  0.449198           0.561856   0.095890
# 4  0.595808    0.645621  0.598930           0.639175   0.328767
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.127586    0.071730                  0.56         0.193038
# 1       0.575862    0.419831                  0.26         0.493671
# 2       0.262069    0.061181                  0.96         0.357595
# 3       0.510345    0.386076                  0.78         0.503165
# 4       0.282759    0.086498                  0.60         0.313291
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# ...

# %% [markdown]
# ## Part 4 - Apply on test and show model performance estimation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
# Load the training and test datasets
train_data = pd.read_csv('wine_train.csv')
test_data = pd.read_csv('wine_test.csv')

# Separate features (X) and target variable (y) for training and test data
X_train = train_data.drop('target', axis=1)  # Drop the target column to get the features
y_train = train_data['target']  # Extract the target column
X_test = test_data.drop('target', axis=1)
y_test = test_data['target']

# Standardize the features (mean=0, std=1)
scaler = StandardScaler()  # Create a StandardScaler object
X_train_scaled = scaler.fit_transform(X_train)  # Fit the scaler on the training data and transform it
X_test_scaled = scaler.transform(X_test)  # Transform the test data using the same scaler

# Train and evaluate Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_scaled, y_train)
y_pred_rf = rf.predict(X_test_scaled)

# Perform cross-validation
cv_scores_rf = cross_val_score(rf, X_train_scaled, y_train, cv=5)
print(f"Random Forest Cross-Validation Scores: {cv_scores_rf}")
print(f"Random Forest Cross-Validation Mean Score: {cv_scores_rf.mean() * 100:.2f}%\n")

# Evaluate Random Forest on test data
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf))

# Calculate performance metrics for Random Forest
accuracy_rf = accuracy_score(y_test, y_pred_rf) * 100
precision_rf = precision_score(y_test, y_pred_rf, average='weighted') * 100
recall_rf = recall_score(y_test, y_pred_rf, average='weighted') * 100
f1_rf = f1_score(y_test, y_pred_rf, average='weighted') * 100

print(f"Random Forest Accuracy: {accuracy_rf:.2f}%")
print(f"Random Forest Precision: {precision_rf:.2f}%")
print(f"Random Forest Recall: {recall_rf:.2f}%")
print(f"Random Forest F1-Score: {f1_rf:.2f}%\n")

# Plot confusion matrix for Random Forest
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Train and evaluate Logistic Regression
log_reg = LogisticRegression(random_state=42, max_iter=1000)
log_reg.fit(X_train_scaled, y_train)
y_pred_log_reg = log_reg.predict(X_test_scaled)

# Perform cross-validation
cv_scores_log_reg = cross_val_score(log_reg, X_train_scaled, y_train, cv=5)
print(f"Logistic Regression Cross-Validation Scores: {cv_scores_log_reg}")
print(f"Logistic Regression Cross-Validation Mean Score: {cv_scores_log_reg.mean() * 100:.2f}%\n")

# Evaluate Logistic Regression on test data
print("Logistic Regression Classification Report:")
print(classification_report(y_test, y_pred_log_reg))

# Calculate performance metrics for Logistic Regression
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg) * 100
precision_log_reg = precision_score(y_test, y_pred_log_reg, average='weighted') * 100
recall_log_reg = recall_score(y_test, y_pred_log_reg, average='weighted') * 100
f1_log_reg = f1_score(y_test, y_pred_log_reg, average='weighted') * 100

print(f"Logistic Regression Accuracy: {accuracy_log_reg:.2f}%")
print(f"Logistic Regression Precision: {precision_log_reg:.2f}%")
print(f"Logistic Regression Recall: {recall_log_reg:.2f}%")
print(f"Logistic Regression F1-Score: {f1_log_reg:.2f}%")

# Plot confusion matrix for Logistic Regression
conf_matrix_log_reg = confusion_matrix(y_test, y_pred_log_reg)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_log_reg, annot=True, fmt='d', cmap='Blues')
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Random Forest Cross-Validation Scores: [1.         0.89655172 1.         1.         0.96428571]
# Random Forest Cross-Validation Mean Score: 97.22%
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Random Forest Accuracy: 100.00%
# Random Forest Precision: 100.00%
# Random Forest Recall: 100.00%
# Random Forest F1-Score: 100.00%
# Logistic Regression Cross-Validation Scores: [1.         0.89655172 1.         0.96428571 1.        ]
# Logistic Regression Cross-Validation Mean Score: 97.22%
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
# ...
